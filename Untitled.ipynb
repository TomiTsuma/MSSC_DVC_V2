# %%
import pandas as pd

# %%
spc = pd.read_csv("../DS-ML88/19_8_2022_global_spectra_datav2dot2_with_rw.csv", engine="c" , index_col=0)
wetchem = pd.read_csv("data/wetchem/lv_filtered.csv", index_col=0)

# %%
spc_2 =spc[(spc.index).isin(wetchem.index)]

# %%
wetchem_2 = wetchem[(wetchem.index).isin(spc.index)]

# %%
spc_2
# Out:
#                        522       524       526       528       530       532  \
# AGD207-408SA0706  2.096135  2.074343  2.077232  2.100555  2.109029  2.113436
# AGD207-431SA0001  2.154667  2.128691  2.090363  2.061056  2.036317  2.019021
# AGD207-431SA0002  2.412217  2.413204  2.360303  2.307860  2.296765  2.316080
# AGD207-431SA0003  2.059137  2.093001  2.136247  2.157497  2.152817  2.144714
# AGD207-431SA0004  2.279650  2.237250  2.218038  2.231755  2.238702  2.222442
# ...                    ...       ...       ...       ...       ...       ...
# CS301SA0020       2.045630  2.069787  2.128691  2.186521  2.180089  2.127234
# CS301SA0021       2.130854  2.172474  2.172629  2.144991  2.153000  2.181448
# CS301SA0023       2.174167  2.143292  2.162553  2.200258  2.199128  2.174309
# CW104SA0052       1.915089  1.907579  2.006204  2.047937  2.043367  2.039258
# CW104SA0053       2.077128  2.040786  2.043095  2.071373  2.064174  2.076678
#
# ...

# %%
wetchem_2
# Out:
#                   organic_carbon  total_nitrogen  aluminium  boron  calcium  \
# sample_code
# AGD102-129SA0001             NaN             NaN        NaN    NaN      NaN
# AGD102-130SA0001             NaN             NaN        NaN   2.89   1990.0
# AGD102-132SA0001             NaN             NaN        NaN    NaN   2850.0
# AGD102-133SA0001             NaN             NaN        NaN    NaN    283.0
# AGD102-133SA0002             NaN             NaN        NaN    NaN   1320.0
# ...                          ...             ...        ...    ...      ...
# I48-1-101SA0001              NaN             NaN        NaN   1.28   3990.0
# I48-1-108SA0001              NaN             NaN        NaN   0.37      NaN
# I48-1-109SA0001              NaN             NaN        NaN   3.52      NaN
# I48-1-111SA0001              NaN             NaN        NaN   0.45   1540.0
# I48-1-112SA0001              NaN             NaN        NaN   0.61   2060.0
#
# ...

# %%
wetchem
# Out:
#                   organic_carbon  total_nitrogen  aluminium  boron  calcium  \
# sample_code
# AGD102-129SA0001             NaN             NaN        NaN    NaN      NaN
# AGD102-130SA0001             NaN             NaN        NaN   2.89   1990.0
# AGD102-132SA0001             NaN             NaN        NaN    NaN   2850.0
# AGD102-133SA0001             NaN             NaN        NaN    NaN    283.0
# AGD102-133SA0002             NaN             NaN        NaN    NaN   1320.0
# ...                          ...             ...        ...    ...      ...
# I48-1-101SA0001              NaN             NaN        NaN   1.28   3990.0
# I48-1-108SA0001              NaN             NaN        NaN   0.37      NaN
# I48-1-109SA0001              NaN             NaN        NaN   3.52      NaN
# I48-1-111SA0001              NaN             NaN        NaN   0.45   1540.0
# I48-1-112SA0001              NaN             NaN        NaN   0.61   2060.0
#
# ...

# %%
spc_2.to_csv("data/20230216-105652/AB_quantized_spectra.csv")

# %%
wetchem_2.to_csv("data/wetchem/lv_filtered.csv")
