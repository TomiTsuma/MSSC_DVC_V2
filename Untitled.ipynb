# %%
import pandas as pd

# %%
spc = pd.read_csv("spc/spc.csv", engine="c" , index_col=0)
wetchem = pd.read_csv("wetchem/wetchem.csv", index_col=0)

# %%
len(wetchem)
# Out:
# 3374

# %%
len(spc)
# Out:
# 3374

# %%
spc_2 =spc[(spc.index).isin(wetchem.index)]

# %%
wetchem_2 = wetchem[(wetchem.index).isin(spc.index)]

# %%
spc_2
# Out:
#                   522       524       526       528       530       532
# sample_id
# CK079SA1362  2.166929  2.177249  2.169873  2.150925  2.140888  2.149560  \
# CK103SA2748  2.371711  2.309733  2.308869  2.321824  2.329884  2.312718
# CI016SA3266  2.150798  2.140677  2.138215  2.146306  2.165076  2.184265
# CA150SA0110  2.157516  2.112731  2.097746  2.091856  2.079349  2.077569
# CF177SA1716  2.074661  2.041011  2.026751  2.034500  2.055215  2.065277
# ...               ...       ...       ...       ...       ...       ...
# CD009SA0020  2.067730  2.058348  2.089870  2.046651  2.022030  2.065215
# CI014SA5736  2.032436  2.001742  1.973515  1.933186  1.913856  1.925148
# CV002SA1764  1.954367  1.953423  1.946556  1.952111  1.967006  1.993248
# CI014SA5430  1.852322  1.842019  1.849856  1.850336  1.855277  1.883636
# CA294SA0017  2.059549  2.071771  2.052268  2.022463  2.004055  2.008785
#
#                   534       536       538       540  ...      3958      3960
# ...

# %%
wetchem_2
# Out:
#              organic_carbon  total_nitrogen  aluminium  boron  calcium
# sample_code
# CA002SA0481             NaN             NaN        NaN   1.87   4850.0  \
# CA002SA0573             NaN             NaN        NaN   0.77   2790.0
# CA022SA0391             NaN             NaN        NaN   0.39    903.0
# CA022SA0528             NaN             NaN        NaN   0.34   1880.0
# CA028SA0124             NaN             NaN        NaN   3.74   4920.0
# ...                     ...             ...        ...    ...      ...
# CW017SA7154             NaN             NaN        NaN    NaN      NaN
# CW017SA7156             NaN             NaN        NaN    NaN      NaN
# CW017SA7159             NaN             NaN        NaN    NaN      NaN
# CW017SA7162             NaN             NaN        NaN    NaN      NaN
# CW017SA7168             NaN             NaN        NaN    NaN      NaN
#
#              copper  ec_salts  exchangeable_acidity   iron  magnesium  ...
# ...

# %%
wetchem
# Out:
#                   organic_carbon  total_nitrogen  aluminium  boron  calcium  \
# sample_code
# AGD102-129SA0001             NaN             NaN        NaN    NaN      NaN
# AGD102-130SA0001             NaN             NaN        NaN   2.89   1990.0
# AGD102-132SA0001             NaN             NaN        NaN    NaN   2850.0
# AGD102-133SA0001             NaN             NaN        NaN    NaN    283.0
# AGD102-133SA0002             NaN             NaN        NaN    NaN   1320.0
# ...                          ...             ...        ...    ...      ...
# I48-1-101SA0001              NaN             NaN        NaN   1.28   3990.0
# I48-1-108SA0001              NaN             NaN        NaN   0.37      NaN
# I48-1-109SA0001              NaN             NaN        NaN   3.52      NaN
# I48-1-111SA0001              NaN             NaN        NaN   0.45   1540.0
# I48-1-112SA0001              NaN             NaN        NaN   0.61   2060.0
#
# ...

# %%
spc_2.to_csv("data/20230216-105652/AB_quantized_spectra.csv")

# %%
wetchem_2.to_csv("data/wetchem/lv_filtered.csv")

# %%
spc_ =spc_2[~(spc_2.index).isin(wetchem_2.index)]

# %%
spc_
# Out:
# Empty DataFrame
# Columns: [522, 524, 526, 528, 530, 532, 534, 536, 538, 540, 542, 544, 546, 548, 550, 552, 554, 556, 558, 560, 562, 564, 566, 568, 570, 572, 574, 576, 578, 580, 582, 584, 586, 588, 590, 592, 594, 596, 598, 600, 602, 604, 606, 608, 610, 612, 614, 616, 618, 620, 622, 624, 626, 628, 630, 632, 634, 636, 638, 640, 642, 644, 646, 648, 650, 652, 654, 656, 658, 660, 662, 664, 666, 668, 670, 672, 674, 676, 678, 680, 682, 684, 686, 688, 690, 692, 694, 696, 698, 700, 702, 704, 706, 708, 710, 712, 714, 716, 718, 720, ...]
# Index: []
#
# [0 rows x 1728 columns]

# %%
wetchem_ =wetchem_2[~(wetchem_2.index).isin(spc.index)]

# %%
wetchem_
# Out:
# Empty DataFrame
# Columns: [organic_carbon, total_nitrogen, aluminium, boron, calcium, copper, ec_salts, exchangeable_acidity, iron, magnesium, manganese, ph, phosphorus, psi, potassium, sodium, sulphur, zinc, cec, clay, sand, silt, phosphorus_olsen, reactive_carbon]
# Index: []
#
# [0 rows x 24 columns]

# %%
df = pd.read_csv("data/20230216-105652/AB_quantized_spectra.csv", engine="c")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '522', '524', '526', '528', '530', '532', '534', '536',
#        '538',
#        ...
#        '3958', '3960', '3962', '3964', '3966', '3968', '3970', '3972', '3974',
#        '3976'],
#       dtype='object', length=1729)

# %%
df.drop("3976", axis=1, inplace=True)

# %%
df.to_csv("data/20230216-105652/AB_quantized_spectra.csv")

# %%
myList = [1, 2, 3, 4, 5]
myList.pop()
print(myList)
# Out:
# [1, 2, 3, 4]
